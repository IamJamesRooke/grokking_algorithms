# %% [markdown]
# # Trees

# %% [markdown]
# ## First Tree
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## File Directories
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from os import listdir
from os.path import isfile, join
from collections import deque

# %%
def printnames(start_dir):
    search_queue = deque()
    search_queue.append(start_dir)
    while search_queue:
        dir = search_queue.popleft()
        for file in sorted(listdir(dir)):
            fullpath = join(dir, file)
            if isfile(fullpath):
                print(file)
            else:
                search_queue.append(fullpath)

printnames('pics')
# Out:
# test1.txt
# test2.txt
# test3.txt
# file1.txt
# file2.txt
# subfile1.txt
# subfile2.txt

# %%
# recursively

from os import listdir
from os.path import isfile, join

def printnames(dir):
    for file in sorted(listdir(dir)):
        fullpath = join(dir, file)
        if isfile(fullpath):
            print(file)
        else:
            printnames(fullpath)

printnames('pics')
# Out:
# file1.txt
# file2.txt
# subfile1.txt
# subfile2.txt
# test1.txt
# test2.txt
# test3.txt

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Depth First Search
#
# ![image.png](attachment:image.png)
#
# **DEPTH FIRST SEARCH CAN'T BE USED TO FIND THE SHORTEST PATH**

# %% [markdown]
# # Better Definition of Trees
#
# ![image.png](attachment:image.png)
#
# **TREES CANNOT HAVE CYCLES**

# %% [markdown]
# ## Binary Trees

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Huffman Coding

# %% [markdown]
# - Let's decode `011100100110000101100100`
# - Transform it to 8 bits: `01110010` - `01100001` - `01100100`
# - On ISO-8859-1:

# %% [markdown]
# Or with this
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
stat -f%z test.txt
# Out:
#   Cell In[7], line 1
#     stat -f%z test.txt
#               ^
# SyntaxError: invalid syntax
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
